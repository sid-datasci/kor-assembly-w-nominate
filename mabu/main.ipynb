# %%
import requests
import pandas as pd

# %%
api_key = ''.join(open('open_assembly_api_key.txt', 'r').readlines()).strip()

# %%
url = 'https://open.assembly.go.kr/portal/openapi/nwbpacrgavhjryiph'
api_dict = {'key': api_key,
            'type': 'json',
            'pIndex': '1',
            'pSize': '100',
            'AGE': '21'}
r = requests.get(url, params=api_dict)

# %%
import json
data = json.loads(r.text)

# %%
data
# Out:
# {'nwbpacrgavhjryiph': [{'head': [{'list_total_count': 3462},
#     {'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}}]},
#   {'row': [{'AGE': '21',
#      'BILL_NO': '2126436',
#      'BILL_NM': '국립묘지의 설치 및 운영에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 232,
#      'YES_TCNT': 232,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-14',
#      'COMMITTEE_PROC_DT': '2023-12-14',
#      'LAW_SUBMIT_DT': '2023-12-14',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_C2A3D1G2C1T3N1O6W5B8M5W5G8I7N9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_C2A3D1G2C1T3N1O6W5B8M5W5G8I7N9',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126458',
#      'BILL_NM': '자동차손해배상 보장법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 192,
#      'YES_TCNT': 189,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-21',
#      'COMMITTEE_PROC_DT': '2023-12-21',
#      'LAW_SUBMIT_DT': '2023-12-21',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_D2B3N1T2T2N0K1Q9S3Q4A0Y6R2P3E6',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2B3N1T2T2N0K1Q9S3Q4A0Y6R2P3E6',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126447',
#      'BILL_NM': '유사수신행위의 규제에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 235,
#      'YES_TCNT': 234,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-14',
#      'COMMITTEE_PROC_DT': '2023-12-14',
#      'LAW_SUBMIT_DT': '2023-12-14',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_T2B3L1O2N1E3J1V6X5F2Q1K6B9N5G0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_T2B3L1O2N1E3J1V6X5F2Q1K6B9N5G0',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126446',
#      'BILL_NM': '전기통신금융사기 피해 방지 및 피해금 환급에 관한 특별법 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 244,
#      'YES_TCNT': 244,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-14',
#      'COMMITTEE_PROC_DT': '2023-12-14',
#      'LAW_SUBMIT_DT': '2023-12-14',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Y2D3T1U2D1G3D1O6S5D0T1V8L5G5S4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Y2D3T1U2D1G3D1O6S5D0T1V8L5G5S4',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126435',
#      'BILL_NM': '공익신고자 보호법 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 238,
#      'YES_TCNT': 237,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-14',
#      'COMMITTEE_PROC_DT': '2023-12-14',
#      'LAW_SUBMIT_DT': '2023-12-14',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_P2F3H1P2Y1K3Q1Y6L5Z4U1D4R0Q2N4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_P2F3H1P2Y1K3Q1Y6L5Z4U1D4R0Q2N4',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126442',
#      'BILL_NM': '사립학교교직원 연금법 일부개정법률안(대안)(교육위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '교육위원장',
#      'COMMITTEE_NM': '교육위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 235,
#      'YES_TCNT': 232,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2024-01-04',
#      'COMMITTEE_PROC_DT': '2024-01-04',
#      'LAW_SUBMIT_DT': '2024-01-04',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_C2B4J0L1Z0Q4L1M7V4Z7Q1X9D0E5D9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_C2B4J0L1Z0Q4L1M7V4Z7Q1X9D0E5D9',
#      'CURR_COMMITTEE_ID': '9700512'},
#     {'AGE': '21',
#      'BILL_NO': '2126441',
#      'BILL_NM': '장애인 등에 대한 특수교육법 일부개정법률안(대안)(교육위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '교육위원장',
#      'COMMITTEE_NM': '교육위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 239,
#      'YES_TCNT': 239,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2024-01-04',
#      'COMMITTEE_PROC_DT': '2024-01-04',
#      'LAW_SUBMIT_DT': '2024-01-04',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_G2T4T0U1Y0N4L1U7G5T3C0G9T4C8S7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2T4T0U1Y0N4L1U7G5T3C0G9T4C8S7',
#      'CURR_COMMITTEE_ID': '9700512'},
#     {'AGE': '21',
#      'BILL_NO': '2126443',
#      'BILL_NM': '가상융합산업 진흥법안(대안)(과학기술정보방송통신위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '과학기술정보방송통신위원장',
#      'COMMITTEE_NM': '과학기술정보방송통신위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 223,
#      'YES_TCNT': 217,
#      'NO_TCNT': 6,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-08',
#      'COMMITTEE_PROC_DT': '2023-12-08',
#      'LAW_SUBMIT_DT': '2023-12-08',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_H2V3N0A2B1V4M1F6E5K3I3U2K5M9Z1',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_H2V3N0A2B1V4M1F6E5K3I3U2K5M9Z1',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126438',
#      'BILL_NM': '지방재정법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 213,
#      'YES_TCNT': 212,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-20',
#      'COMMITTEE_PROC_DT': '2023-12-20',
#      'LAW_SUBMIT_DT': '2023-12-21',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_J2P3B1F2L1X9A1J9J4T3A1T5O6K9L5',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_J2P3B1F2L1X9A1J9J4T3A1T5O6K9L5',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126454',
#      'BILL_NM': '경찰공무원 보건안전 및 복지 기본법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 206,
#      'YES_TCNT': 199,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 7,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_I2K3Z1V1O2K1C2M2V3V9Q2Z1A6D5B7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_I2K3Z1V1O2K1C2M2V3V9Q2Z1A6D5B7',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126463',
#      'BILL_NM': '고향사랑 기부금에 관한 법률 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 208,
#      'YES_TCNT': 206,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_I2Q3C1W1P2P1Z2J2E1W4G0R0S4B7F3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_I2Q3C1W1P2P1Z2J2E1W4G0R0S4B7F3',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126467',
#      'BILL_NM': '관광진흥법 일부개정법률안(대안)(문화체육관광위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '문화체육관광위원장',
#      'COMMITTEE_NM': '문화체육관광위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 209,
#      'YES_TCNT': 207,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-19',
#      'COMMITTEE_PROC_DT': '2023-12-19',
#      'LAW_SUBMIT_DT': '2023-12-19',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_D2R3O1M2I1U8I1U6K2R2P4Q4L9I8P8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2R3O1M2I1U8I1U6K2R2P4Q4L9I8P8',
#      'CURR_COMMITTEE_ID': '9700513'},
#     {'AGE': '21',
#      'BILL_NO': '2126466',
#      'BILL_NM': '체육시설의 설치·이용에 관한 법률 일부개정법률안(대안)(문화체육관광위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '문화체육관광위원장',
#      'COMMITTEE_NM': '문화체육관광위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 207,
#      'YES_TCNT': 205,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-19',
#      'COMMITTEE_PROC_DT': '2023-12-19',
#      'LAW_SUBMIT_DT': '2023-12-19',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_U2Y3T1Q2C1C8W1F6N2L5R4J0P8C9G8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2Y3T1Q2C1C8W1F6N2L5R4J0P8C9G8',
#      'CURR_COMMITTEE_ID': '9700513'},
#     {'AGE': '21',
#      'BILL_NO': '2126451',
#      'BILL_NM': '중소기업창업 지원법 일부개정법률안(대안)(산업통상자원중소벤처기업위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '산업통상자원중소벤처기업위원장',
#      'COMMITTEE_NM': '산업통상자원중소벤처기업위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 204,
#      'YES_TCNT': 203,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-14',
#      'COMMITTEE_PROC_DT': '2023-12-14',
#      'LAW_SUBMIT_DT': '2023-12-15',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_O2M3X1X2W0B6O1I4B3E1J4U1N1X2I5',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2M3X1X2W0B6O1I4B3E1J4U1N1X2I5',
#      'CURR_COMMITTEE_ID': '9700481'},
#     {'AGE': '21',
#      'BILL_NO': '2126453',
#      'BILL_NM': '약사법 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 206,
#      'YES_TCNT': 200,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 6,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_O2Q3S1V1X2C2E2A0B4Z2L0N3G4J9O2',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2Q3S1V1X2C2E2A0B4Z2L0N3G4J9O2',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126439',
#      'BILL_NM': '전공의의 수련환경 개선 및 지위 향상을 위한 법률 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 208,
#      'YES_TCNT': 207,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-20',
#      'COMMITTEE_PROC_DT': '2023-12-20',
#      'LAW_SUBMIT_DT': '2023-12-20',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_D2R3Z1T2K1R8A2C0K1K6B3R5J7C2H9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2R3Z1T2K1R8A2C0K1K6B3R5J7C2H9',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126440',
#      'BILL_NM': '첨단재생의료 및 첨단바이오의약품 안전 및 지원에 관한 법률  일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 207,
#      'YES_TCNT': 194,
#      'NO_TCNT': 8,
#      'BLANK_TCNT': 5,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-20',
#      'COMMITTEE_PROC_DT': '2023-12-20',
#      'LAW_SUBMIT_DT': '2023-12-20',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_F2G3U1S2O1O8L2Q0X1C8L3B7S0X5F0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_F2G3U1S2O1O8L2Q0X1C8L3B7S0X5F0',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126452',
#      'BILL_NM': '국민건강보험법 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 203,
#      'YES_TCNT': 201,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-20',
#      'COMMITTEE_PROC_DT': '2023-12-20',
#      'LAW_SUBMIT_DT': '2023-12-20',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_X2L3G1Y2W1A9N1H5X0H6A1H9J0F1I9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_X2L3G1Y2W1A9N1H5X0H6A1H9J0F1I9',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126456',
#      'BILL_NM': '환경영향평가법 일부개정법률안(대안)(환경노동위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '환경노동위원장',
#      'COMMITTEE_NM': '환경노동위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 197,
#      'YES_TCNT': 187,
#      'NO_TCNT': 5,
#      'BLANK_TCNT': 5,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-22',
#      'COMMITTEE_PROC_DT': '2023-12-28',
#      'LAW_SUBMIT_DT': '2023-12-28',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_V2L3S1T2W1W9J1L6T0P4A0Y6S0O1R5',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_V2L3S1T2W1W9J1L6T0P4A0Y6S0O1R5',
#      'CURR_COMMITTEE_ID': '9700038'},
#     {'AGE': '21',
#      'BILL_NO': '2126448',
#      'BILL_NM': '교통약자의 이동편의 증진법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 199,
#      'YES_TCNT': 199,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-21',
#      'COMMITTEE_PROC_DT': '2023-12-21',
#      'LAW_SUBMIT_DT': '2023-12-21',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_G2A3D1B2Q2V0T1U9G3G5G5K8B5D1P0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2A3D1B2Q2V0T1U9G3G5G5K8B5D1P0',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126449',
#      'BILL_NM': '자동차관리법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 195,
#      'YES_TCNT': 193,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-21',
#      'COMMITTEE_PROC_DT': '2023-12-21',
#      'LAW_SUBMIT_DT': '2023-12-21',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_N2O3Z1X2L2M0K1K9K3Y5Z1X0Q7Y0H6',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_N2O3Z1X2L2M0K1K9K3Y5Z1X0Q7Y0H6',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126444',
#      'BILL_NM': '하도급거래 공정화에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 241,
#      'YES_TCNT': 240,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-31',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-14',
#      'COMMITTEE_PROC_DT': '2023-12-14',
#      'LAW_SUBMIT_DT': '2023-12-14',
#      'LAW_PRESENT_DT': '2024-01-31',
#      'LAW_PROC_DT': '2024-01-31',
#      'RGS_PRESENT_DT': '2024-02-01',
#      'RGS_PROC_DT': '2024-02-01',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_D2S3U1Z2P1H3V1H7E0J8U5C4G5O4R7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2S3U1Z2P1H3V1H7E0J8U5C4G5O4R7',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126376',
#      'BILL_NM': '정부조직법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 220,
#      'YES_TCNT': 218,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-20',
#      'COMMITTEE_PROC_DT': '2023-12-20',
#      'LAW_SUBMIT_DT': '2023-12-21',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Q2H3A1O2B1D9I1C9E4Y4K3F5R3N2Q8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2H3A1O2B1D9I1C9E4Y4K3F5R3N2Q8',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126389',
#      'BILL_NM': '경비업법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 215,
#      'YES_TCNT': 214,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-08',
#      'COMMITTEE_PROC_DT': '2023-12-08',
#      'LAW_SUBMIT_DT': '2023-12-08',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_B2W3H1V2F0E7I1F8O4O8K0D2K9U5I0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_B2W3H1V2F0E7I1F8O4O8K0D2K9U5I0',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126381',
#      'BILL_NM': '경찰공무원법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 214,
#      'YES_TCNT': 212,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_E2N3J1Q1C2W1A2C2B3W5N4B4N7R2G2',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_E2N3J1Q1C2W1A2C2B3W5N4B4N7R2G2',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126373',
#      'BILL_NM': '도로교통법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 212,
#      'YES_TCNT': 209,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 3,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-08',
#      'COMMITTEE_PROC_DT': '2023-12-08',
#      'LAW_SUBMIT_DT': '2023-12-08',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_O2S3R1W2B0T7X1G8T5I0I4O6V5M3T7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2S3R1W2B0T7X1G8T5I0I4O6V5M3T7',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126384',
#      'BILL_NM': '소방공무원 보건안전 및 복지 기본법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 219,
#      'YES_TCNT': 215,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 4,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-08',
#      'COMMITTEE_PROC_DT': '2023-12-08',
#      'LAW_SUBMIT_DT': '2023-12-08',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_S2M3M1D2F0C7A1D8H5Y1W3U5T6R9S7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_S2M3M1D2F0C7A1D8H5Y1W3U5T6R9S7',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126380',
#      'BILL_NM': '전통사찰의 보존 및 지원에 관한 법률 일부개정법률안(대안)(문화체육관광위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '문화체육관광위원장',
#      'COMMITTEE_NM': '문화체육관광위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 218,
#      'YES_TCNT': 213,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 4,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-19',
#      'COMMITTEE_PROC_DT': '2023-12-19',
#      'LAW_SUBMIT_DT': '2023-12-19',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_K2O3B1K2M1F8C1J6D1Y9J5H4I1L7U4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_K2O3B1K2M1F8C1J6D1Y9J5H4I1L7U4',
#      'CURR_COMMITTEE_ID': '9700513'},
#     {'AGE': '21',
#      'BILL_NO': '2126382',
#      'BILL_NM': '매장문화재 보호 및 조사에 관한 법률 일부개정법률안(대안)(문화체육관광위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '문화체육관광위원장',
#      'COMMITTEE_NM': '문화체육관광위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 222,
#      'YES_TCNT': 220,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-19',
#      'COMMITTEE_PROC_DT': '2023-12-19',
#      'LAW_SUBMIT_DT': '2023-12-19',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_V2X3K1O2K1O8V1J6S2N7H0F4Q3H7O3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_V2X3K1O2K1O8V1J6S2N7H0F4Q3H7O3',
#      'CURR_COMMITTEE_ID': '9700513'},
#     {'AGE': '21',
#      'BILL_NO': '2126383',
#      'BILL_NM': '문화재보호법 일부개정법률안(대안)(문화체육관광위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '문화체육관광위원장',
#      'COMMITTEE_NM': '문화체육관광위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 221,
#      'YES_TCNT': 220,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-19',
#      'COMMITTEE_PROC_DT': '2023-12-19',
#      'LAW_SUBMIT_DT': '2023-12-19',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_R2K3A1D2C1M8U1F6I2W7V5S2B2O3E0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2K3A1D2C1M8U1F6I2W7V5S2B2O3E0',
#      'CURR_COMMITTEE_ID': '9700513'},
#     {'AGE': '21',
#      'BILL_NO': '2126377',
#      'BILL_NM': '대외무역법 일부개정법률안(대안)(산업통상자원중소벤처기업위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '산업통상자원중소벤처기업위원장',
#      'COMMITTEE_NM': '산업통상자원중소벤처기업위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 214,
#      'YES_TCNT': 212,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_O2P3P1B1K2N9F1P7S2G8P2D8Z5U5H0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2P3P1B1K2N9F1P7S2G8P2D8Z5U5H0',
#      'CURR_COMMITTEE_ID': '9700481'},
#     {'AGE': '21',
#      'BILL_NO': '2126374',
#      'BILL_NM': '지역신용보증재단법 일부개정법률안(대안)(산업통상자원중소벤처기업위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '산업통상자원중소벤처기업위원장',
#      'COMMITTEE_NM': '산업통상자원중소벤처기업위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 224,
#      'YES_TCNT': 221,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 3,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2023-12-19',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_U2Z3E1Q1U2P1D1T3V1J5H1X4K1C1O1',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2Z3E1Q1U2P1D1T3V1J5H1X4K1C1O1',
#      'CURR_COMMITTEE_ID': '9700481'},
#     {'AGE': '21',
#      'BILL_NO': '2126378',
#      'BILL_NM': '부정경쟁방지 및 영업비밀보호에 관한 법률 일부개정법률안(대안)(산업통상자원중소벤처기업위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '산업통상자원중소벤처기업위원장',
#      'COMMITTEE_NM': '산업통상자원중소벤처기업위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 230,
#      'YES_TCNT': 229,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_R2X3B1H1W2U9R1W7T3Q2C5L8A7U4V3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2X3B1H1W2U9R1W7T3Q2C5L8A7U4V3',
#      'CURR_COMMITTEE_ID': '9700481'},
#     {'AGE': '21',
#      'BILL_NO': '2126379',
#      'BILL_NM': '특허법 일부개정법률안(대안)(산업통상자원중소벤처기업위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '산업통상자원중소벤처기업위원장',
#      'COMMITTEE_NM': '산업통상자원중소벤처기업위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 230,
#      'YES_TCNT': 227,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 3,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': None,
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_T2V3Y1J1J2B9V1J8A0F6Q0R1G3Q2E4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_T2V3Y1J1J2B9V1J8A0F6Q0R1G3Q2E4',
#      'CURR_COMMITTEE_ID': '9700481'},
#     {'AGE': '21',
#      'BILL_NO': '2126370',
#      'BILL_NM': '식품위생법 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 214,
#      'YES_TCNT': 212,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-08-25',
#      'COMMITTEE_PROC_DT': '2023-08-25',
#      'LAW_SUBMIT_DT': '2023-08-25',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_W2Q3C0V8F2F4O1L0B2G0P5A8N7H2M8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2Q3C0V8F2F4O1L0B2G0P5A8N7H2M8',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126375',
#      'BILL_NM': '장애인복지법 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 212,
#      'YES_TCNT': 211,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-09-21',
#      'COMMITTEE_PROC_DT': '2023-09-21',
#      'LAW_SUBMIT_DT': '2023-09-21',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_U2Z3F0K9J2V0S1D3M3S2O1K4N4E6U6',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2Z3F0K9J2V0S1D3M3S2O1K4N4E6U6',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126372',
#      'BILL_NM': '영유아보육법 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 216,
#      'YES_TCNT': 216,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-09-21',
#      'COMMITTEE_PROC_DT': '2023-09-21',
#      'LAW_SUBMIT_DT': '2023-09-21',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Z2F3F0B9I2M0O1M3H3V3A0B5I7E6N3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2F3F0B9I2M0O1M3H3V3A0B5I7E6N3',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126363',
#      'BILL_NM': '인천국제공항공사법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 218,
#      'YES_TCNT': 209,
#      'NO_TCNT': 3,
#      'BLANK_TCNT': 6,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-07',
#      'COMMITTEE_PROC_DT': '2023-12-07',
#      'LAW_SUBMIT_DT': '2023-12-07',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_I2J3H1W2Q0R6E1G5J5T6G0Y9Q3G1N4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_I2J3H1W2Q0R6E1G5J5T6G0Y9Q3G1N4',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126364',
#      'BILL_NM': '공항시설법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 211,
#      'YES_TCNT': 210,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-09-21',
#      'COMMITTEE_PROC_DT': '2023-09-21',
#      'LAW_SUBMIT_DT': '2023-09-21',
#      'LAW_PRESENT_DT': '2023-12-19',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Z2R3H0W9R2P0V1J5S1U4H3Y3K9V2R9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2R3H0W9R2P0V1J5S1U4H3Y3K9V2R9',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126365',
#      'BILL_NM': '기업도시개발 특별법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 219,
#      'YES_TCNT': 198,
#      'NO_TCNT': 6,
#      'BLANK_TCNT': 15,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_I2L3E1B1M2I9R1G4I1D2P4Q3T2T0J5',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_I2L3E1B1M2I9R1G4I1D2P4Q3T2T0J5',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126366',
#      'BILL_NM': '도로법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 215,
#      'YES_TCNT': 215,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-07',
#      'COMMITTEE_PROC_DT': '2023-12-07',
#      'LAW_SUBMIT_DT': '2023-12-07',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Q2W3U1Y2J0Z6K1E5M5P5C2C9G1A5F7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2W3U1Y2J0Z6K1E5M5P5C2C9G1A5F7',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126368',
#      'BILL_NM': '자동차관리법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 214,
#      'YES_TCNT': 213,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-07',
#      'COMMITTEE_PROC_DT': '2023-12-07',
#      'LAW_SUBMIT_DT': '2023-12-07',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Z2A3V1X2F0L6P1Y5L5K3B2F0G6O1B3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2A3V1X2F0L6P1Y5L5K3B2F0G6O1B3',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126367',
#      'BILL_NM': '여객자동차 운수사업법 일부개정법률안(대안)(국토교통위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국토교통위원장',
#      'COMMITTEE_NM': '국토교통위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 215,
#      'YES_TCNT': 213,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-09-21',
#      'COMMITTEE_PROC_DT': '2023-09-21',
#      'LAW_SUBMIT_DT': '2023-09-21',
#      'LAW_PRESENT_DT': '2023-12-19',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_L2C3X0K9B2D0Z1D5R1R5E5D2V9F9I5',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_L2C3X0K9B2D0Z1D5R1R5E5D2V9F9I5',
#      'CURR_COMMITTEE_ID': '9700407'},
#     {'AGE': '21',
#      'BILL_NO': '2126362',
#      'BILL_NM': '형사소송법 일부개정법률안(대안)(법제사법위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '법제사법위원장',
#      'COMMITTEE_NM': '법제사법위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 226,
#      'YES_TCNT': 224,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2024-01-24',
#      'COMMITTEE_PROC_DT': '2024-01-24',
#      'LAW_SUBMIT_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_PROC_DT': None,
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_J2E4S0L1S2F3U1T5U2S3S4C7P5H2Z6',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_J2E4S0L1S2F3U1T5U2S3S4C7P5H2Z6',
#      'CURR_COMMITTEE_ID': '9700006'},
#     {'AGE': '21',
#      'BILL_NO': '2126390',
#      'BILL_NM': '5·18민주유공자예우 및 단체설립에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 237,
#      'YES_TCNT': 237,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_V2O3V1E1J2X9N2N0V0G4U0G5V0X6T0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_V2O3V1E1J2X9N2N0V0G4U0G5V0X6T0',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126391',
#      'BILL_NM': '고엽제후유의증 등 환자지원 및 단체설립에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 239,
#      'YES_TCNT': 237,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_B2Z3W1V1N2X9Z1E9Z5C7N4J2N2S4N0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_B2Z3W1V1N2X9Z1E9Z5C7N4J2N2S4N0',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126392',
#      'BILL_NM': '국가유공자 등 예우 및 지원에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 240,
#      'YES_TCNT': 239,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Y2B3J1Z1O2G9S1A9Y5Z5O4E8E4R8I3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Y2B3J1Z1O2G9S1A9Y5Z5O4E8E4R8I3',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126393',
#      'BILL_NM': '독립유공자예우에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 242,
#      'YES_TCNT': 242,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Z2K3G1U1N2M9A1S9C5G8W4J1I7K8V0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2K3G1U1N2M9A1S9C5G8W4J1I7K8V0',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126395',
#      'BILL_NM': '보훈보상대상자 지원에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 240,
#      'YES_TCNT': 239,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_G2A3A1N1V2V9S1W9A5A9X5W2A9W0V6',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2A3A1N1V2V9S1W9A5A9X5W2A9W0V6',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126396',
#      'BILL_NM': '참전유공자 예우 및 단체설립에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 245,
#      'YES_TCNT': 244,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_R2H3V1O1K2U9R2J0E0P2E3F1X7R1P2',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2H3V1O1K2U9R2J0E0P2E3F1X7R1P2',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126397',
#      'BILL_NM': '특수임무유공자 예우 및 단체설립에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 243,
#      'YES_TCNT': 241,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_G2S3M1E1L2H9F2I0X0C1S0V8Q4F8Q7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2S3M1E1L2H9F2I0X0C1S0V8Q4F8Q7',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126394',
#      'BILL_NM': '독점규제 및 공정거래에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 229,
#      'YES_TCNT': 220,
#      'NO_TCNT': 5,
#      'BLANK_TCNT': 4,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_U2E3N1S1L2Z9J1B8D5F1Q1T7K3D0W4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2E3N1S1L2Z9J1B8D5F1Q1T7K3D0W4',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126387',
#      'BILL_NM': '전자상거래 등에서의 소비자보호에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 229,
#      'YES_TCNT': 227,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
#      'LAW_PROC_DT': '2024-01-24',
#      'RGS_PRESENT_DT': '2024-01-25',
#      'RGS_PROC_DT': '2024-01-25',
#      'CURR_TRANS_DT': '2024-02-02',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_O2D3J1Q1T2Z9S1N8L5T6Y1E1A7F2E4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2D3J1Q1T2Z9S1N8L5T6Y1E1A7F2E4',
#      'CURR_COMMITTEE_ID': '9700008'},
#     {'AGE': '21',
#      'BILL_NO': '2126399',
#      'BILL_NM': '자본시장과 금융투자업에 관한 법률 일부개정법률안(대안)(정무위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '정무위원장',
#      'COMMITTEE_NM': '정무위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 233,
#      'YES_TCNT': 232,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-24',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-30',
#      'COMMITTEE_PROC_DT': '2023-11-30',
#      'LAW_SUBMIT_DT': '2023-11-30',
#      'LAW_PRESENT_DT': '2024-01-24',
# ...
#      'BLANK_TCNT': 4,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2024-01-08',
#      'COMMITTEE_PROC_DT': '2024-01-08',
#      'LAW_SUBMIT_DT': '2024-01-08',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-26',
#      'BILL_ID': 'PRC_Q2A4U0K1N0Q8B1U0B4Y2B3H5L0V4V9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2A4U0K1N0Q8B1U0B4Y2B3H5L0V4V9',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126183',
#      'BILL_NM': '우주개발 진흥법 일부개정법률안(대안)(과학기술정보방송통신위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '과학기술정보방송통신위원장',
#      'COMMITTEE_NM': '과학기술정보방송통신위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 262,
#      'YES_TCNT': 260,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2024-01-08',
#      'COMMITTEE_PROC_DT': '2024-01-08',
#      'LAW_SUBMIT_DT': '2024-01-08',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-26',
#      'BILL_ID': 'PRC_L2I4B0Y1U0E8S1B0E4W3N1K4O6Y1X1',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_L2I4B0Y1U0E8S1B0E4W3N1K4O6Y1X1',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126180',
#      'BILL_NM': '이동통신단말장치 유통구조 개선에 관한 법률 일부개정법률안(대안)(과학기술정보방송통신위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '과학기술정보방송통신위원장',
#      'COMMITTEE_NM': '과학기술정보방송통신위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 258,
#      'YES_TCNT': 256,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-08',
#      'COMMITTEE_PROC_DT': '2023-12-08',
#      'LAW_SUBMIT_DT': '2023-12-08',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_J2V3U1R2P0N7M1C5E1E1L5Z8L9C5L1',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_J2V3U1R2P0N7M1C5E1E1L5Z8L9C5L1',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126182',
#      'BILL_NM': '전기통신사업법 일부개정법률안(대안)(과학기술정보방송통신위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '과학기술정보방송통신위원장',
#      'COMMITTEE_NM': '과학기술정보방송통신위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 259,
#      'YES_TCNT': 255,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 4,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-09-21',
#      'COMMITTEE_PROC_DT': '2023-09-21',
#      'LAW_SUBMIT_DT': '2023-09-21',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_N2O3R0W9S2X0G1Y9E0M7B4Y6L5S1R0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_N2O3R0W9S2X0G1Y9E0M7B4Y6L5S1R0',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126179',
#      'BILL_NM': '여성과학기술인 육성 및 지원에 관한 법률 일부개정법률안(대안)(과학기술정보방송통신위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '과학기술정보방송통신위원장',
#      'COMMITTEE_NM': '과학기술정보방송통신위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 260,
#      'YES_TCNT': 257,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 3,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-03-21',
#      'COMMITTEE_PROC_DT': '2023-05-24',
#      'LAW_SUBMIT_DT': '2023-05-24',
#      'LAW_PRESENT_DT': '2023-09-13',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_E2Q3N0Y3L1I7A1A6D5F0C2N3R6R7Y4',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_E2Q3N0Y3L1I7A1A6D5F0C2N3R6R7Y4',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126185',
#      'BILL_NM': '방송법 일부개정법률안(대안)(과학기술정보방송통신위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '과학기술정보방송통신위원장',
#      'COMMITTEE_NM': '과학기술정보방송통신위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 266,
#      'YES_TCNT': 258,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 8,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-12-08',
#      'COMMITTEE_PROC_DT': '2023-12-08',
#      'LAW_SUBMIT_DT': '2023-12-08',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_W2V3M1X2J0O7L1D5M1T4A5N3B2B3F3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2V3M1X2J0O7L1D5M1T4A5N3B2B3F3',
#      'CURR_COMMITTEE_ID': '9700479'},
#     {'AGE': '21',
#      'BILL_NO': '2126210',
#      'BILL_NM': '북한이탈주민의 보호 및 정착지원에 관한 법률 일부개정법률안(외교통일위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '외교통일위원장',
#      'COMMITTEE_NM': '외교통일위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 243,
#      'YES_TCNT': 243,
#      'NO_TCNT': None,
#      'BLANK_TCNT': None,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': None,
#      'COMMITTEE_PROC_DT': None,
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_Q2V3U1A1Y2J3E1F4P3K2P2V9K9I0V2',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2V3U1A1Y2J3E1F4P3K2P2V9K9I0V2',
#      'CURR_COMMITTEE_ID': '9700409'},
#     {'AGE': '21',
#      'BILL_NO': '2126184',
#      'BILL_NM': '군인의 지위 및 복무에 관한 기본법 일부개정법률안(대안)(국방위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국방위원장',
#      'COMMITTEE_NM': '국방위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 225,
#      'YES_TCNT': 224,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-01',
#      'COMMITTEE_PROC_DT': '2023-11-01',
#      'LAW_SUBMIT_DT': '2023-11-01',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_M2V3N1B0W3Q0C1E4E1T8Z5J4D6F8Y7',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_M2V3N1B0W3Q0C1E4E1T8Z5J4D6F8Y7',
#      'CURR_COMMITTEE_ID': '9700019'},
#     {'AGE': '21',
#      'BILL_NO': '2126181',
#      'BILL_NM': '병역법 일부개정법률안(대안)(국방위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국방위원장',
#      'COMMITTEE_NM': '국방위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 230,
#      'YES_TCNT': 229,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_E2M3A1Y1T2F1C1Q7R4Y5H2Q6K7M0Q8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_E2M3A1Y1T2F1C1Q7R4Y5H2Q6K7M0Q8',
#      'CURR_COMMITTEE_ID': '9700019'},
#     {'AGE': '21',
#      'BILL_NO': '2126195',
#      'BILL_NM': '방위사업법 일부개정법률안(대안)(국방위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '국방위원장',
#      'COMMITTEE_NM': '국방위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 231,
#      'YES_TCNT': 215,
#      'NO_TCNT': 3,
#      'BLANK_TCNT': 13,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_V2U3S1Y1N2I1D1U7L4Z1R1W0H3N8J0',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_V2U3S1Y1N2I1D1U7L4Z1R1W0H3N8J0',
#      'CURR_COMMITTEE_ID': '9700019'},
#     {'AGE': '21',
#      'BILL_NO': '2126204',
#      'BILL_NM': '승강기 안전관리법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 222,
#      'YES_TCNT': 216,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 5,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_U2Z3U1E1H2C1A2Z2R1Q6R3F3D1C6O8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2Z3U1E1H2C1A2Z2R1Q6R3F3D1C6O8',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126218',
#      'BILL_NM': '경비업법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 222,
#      'YES_TCNT': 219,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 2,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_H2J3Q1B1I2K1E2A2N3C6L4F0D7G5Z3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_H2J3Q1B1I2K1E2A2N3C6L4F0D7G5Z3',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126223',
#      'BILL_NM': '경찰관 직무집행법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 226,
#      'YES_TCNT': 222,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 3,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_Y2G3V1Q1H2K1G2T2R3S6R1E7Z3W1O9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Y2G3V1Q1H2K1G2T2R3S6R1E7Z3W1O9',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126215',
#      'BILL_NM': '도로교통법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 224,
#      'YES_TCNT': 223,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_N2J3F1Q1H2G1I2O2E3E8Y4W2K2N3J1',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_N2J3F1Q1H2G1I2O2E3E8Y4W2K2N3J1',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126203',
#      'BILL_NM': '제주특별자치도 설치 및 국제자유도시 조성을 위한 특별법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 216,
#      'YES_TCNT': 211,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 5,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-05-24',
#      'COMMITTEE_PROC_DT': '2023-05-24',
#      'LAW_SUBMIT_DT': '2023-05-24',
#      'LAW_PRESENT_DT': '2023-07-26',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_W2P3C0W5F2X4F1T6A1B8O4O8O1Q0E1',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2P3C0W5F2X4F1T6A1B8O4O8O1Q0E1',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126226',
#      'BILL_NM': '제주4·3사건 진상규명 및 희생자 명예회복에 관한 특별법 일부개정법률안(대안)(행정안전위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '행정안전위원장',
#      'COMMITTEE_NM': '행정안전위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 211,
#      'YES_TCNT': 201,
#      'NO_TCNT': 1,
#      'BLANK_TCNT': 9,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-19',
#      'ANNOUNCE_DT': '2024-01-30',
#      'BILL_ID': 'PRC_A2I3H1Y1R2E2Q2T1E4L8P1E4A5I8V9',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_A2I3H1Y1R2E2Q2T1E4L8P1E4A5I8V9',
#      'CURR_COMMITTEE_ID': '9700480'},
#     {'AGE': '21',
#      'BILL_NO': '2126216',
#      'BILL_NM': '마약류 관리에 관한 법률 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 229,
#      'YES_TCNT': 228,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 1,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_J2L3Y1F1Q2A2C2P0L4Y0D1M1D1H0C3',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_J2L3Y1F1Q2A2C2P0L4Y0D1M1D1H0C3',
#      'CURR_COMMITTEE_ID': '9700341'},
#     {'AGE': '21',
#      'BILL_NO': '2126219',
#      'BILL_NM': '화장품법 일부개정법률안(대안)(보건복지위원장)',
#      'BILL_KIND': '법률안',
#      'PROPOSER': '보건복지위원장',
#      'COMMITTEE_NM': '보건복지위원회',
#      'PROC_RESULT_CD': '원안가결',
#      'VOTE_TCNT': 227,
#      'YES_TCNT': 224,
#      'NO_TCNT': None,
#      'BLANK_TCNT': 3,
#      'PROPOSE_DT': '2024-01-08',
#      'COMMITTEE_SUBMIT_DT': None,
#      'COMMITTEE_PRESENT_DT': '2023-11-23',
#      'COMMITTEE_PROC_DT': '2023-11-23',
#      'LAW_SUBMIT_DT': '2023-11-23',
#      'LAW_PRESENT_DT': '2024-01-08',
#      'LAW_PROC_DT': '2024-01-08',
#      'RGS_PRESENT_DT': '2024-01-09',
#      'RGS_PROC_DT': '2024-01-09',
#      'CURR_TRANS_DT': '2024-01-26',
#      'ANNOUNCE_DT': None,
#      'BILL_ID': 'PRC_G2X3R1R1K2H2Y2R0P4B2E5J4D7N5V8',
#      'LINK_URL': 'https://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2X3R1R1K2H2Y2R0P4B2E5J4D7N5V8',
#      'CURR_COMMITTEE_ID': '9700341'}]}]}

# %%
len(data['nwbpacrgavhjryiph'][1]['row'])
# Out:
# 100

# %%
df = pd.json_normalize(data['nwbpacrgavhjryiph'][1]['row'])

# %%
df
# Out:
#    AGE  BILL_NO                                            BILL_NM BILL_KIND  \
# 0   21  2126436            국립묘지의 설치 및 운영에 관한 법률 일부개정법률안(대안)(정무위원장)       법률안
# 1   21  2126458                   자동차손해배상 보장법 일부개정법률안(대안)(국토교통위원장)       법률안
# 2   21  2126447               유사수신행위의 규제에 관한 법률 일부개정법률안(대안)(정무위원장)       법률안
# 3   21  2126446  전기통신금융사기 피해 방지 및 피해금 환급에 관한 특별법 일부개정법률안(대안)(정무...       법률안
# 4   21  2126435                       공익신고자 보호법 일부개정법률안(대안)(정무위원장)       법률안
# ..  ..      ...                                                ...       ...
# 95  21  2126215                         도로교통법 일부개정법률안(대안)(행정안전위원장)       법률안
# 96  21  2126203  제주특별자치도 설치 및 국제자유도시 조성을 위한 특별법 일부개정법률안(대안)(행정안...       법률안
# 97  21  2126226  제주4·3사건 진상규명 및 희생자 명예회복에 관한 특별법 일부개정법률안(대안)(행정...       법률안
# 98  21  2126216                 마약류 관리에 관한 법률 일부개정법률안(대안)(보건복지위원장)       법률안
# 99  21  2126219                          화장품법 일부개정법률안(대안)(보건복지위원장)       법률안
#
#    PROPOSER COMMITTEE_NM PROC_RESULT_CD  VOTE_TCNT  YES_TCNT  NO_TCNT  ...  \
# 0     정무위원장        정무위원회           원안가결      232.0     232.0      NaN  ...
# 1   국토교통위원장      국토교통위원회           원안가결      192.0     189.0      1.0  ...
# 2     정무위원장        정무위원회           원안가결      235.0     234.0      NaN  ...
# 3     정무위원장        정무위원회           원안가결      244.0     244.0      NaN  ...
# 4     정무위원장        정무위원회           원안가결      238.0     237.0      NaN  ...
# ..      ...          ...            ...        ...       ...      ...  ...
# 95  행정안전위원장      행정안전위원회           원안가결      224.0     223.0      NaN  ...
# 96  행정안전위원장      행정안전위원회           원안가결      216.0     211.0      NaN  ...
# 97  행정안전위원장      행정안전위원회           원안가결      211.0     201.0      1.0  ...
# 98  보건복지위원장      보건복지위원회           원안가결      229.0     228.0      NaN  ...
# 99  보건복지위원장      보건복지위원회           원안가결      227.0     224.0      NaN  ...
#
#     LAW_SUBMIT_DT LAW_PRESENT_DT LAW_PROC_DT RGS_PRESENT_DT RGS_PROC_DT  \
# 0      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 1      2023-12-21     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 2      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 3      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 4      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# ..            ...            ...         ...            ...         ...
# 95     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
# 96     2023-05-24     2023-07-26  2024-01-08     2024-01-09  2024-01-09
# 97     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
# 98     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
# 99     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
#
#    CURR_TRANS_DT ANNOUNCE_DT                             BILL_ID  \
# 0           None        None  PRC_C2A3D1G2C1T3N1O6W5B8M5W5G8I7N9
# 1           None        None  PRC_D2B3N1T2T2N0K1Q9S3Q4A0Y6R2P3E6
# 2           None        None  PRC_T2B3L1O2N1E3J1V6X5F2Q1K6B9N5G0
# 3           None        None  PRC_Y2D3T1U2D1G3D1O6S5D0T1V8L5G5S4
# 4           None        None  PRC_P2F3H1P2Y1K3Q1Y6L5Z4U1D4R0Q2N4
# ..           ...         ...                                 ...
# 95    2024-01-19  2024-01-30  PRC_N2J3F1Q1H2G1I2O2E3E8Y4W2K2N3J1
# 96    2024-01-19  2024-01-30  PRC_W2P3C0W5F2X4F1T6A1B8O4O8O1Q0E1
# 97    2024-01-19  2024-01-30  PRC_A2I3H1Y1R2E2Q2T1E4L8P1E4A5I8V9
# 98    2024-01-26        None  PRC_J2L3Y1F1Q2A2C2P0L4Y0D1M1D1H0C3
# 99    2024-01-26        None  PRC_G2X3R1R1K2H2Y2R0P4B2E5J4D7N5V8
#
#                                              LINK_URL CURR_COMMITTEE_ID
# 0   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# 1   https://likms.assembly.go.kr/bill/billDetail.d...           9700407
# 2   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# 3   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# 4   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# ..                                                ...               ...
# 95  https://likms.assembly.go.kr/bill/billDetail.d...           9700480
# 96  https://likms.assembly.go.kr/bill/billDetail.d...           9700480
# 97  https://likms.assembly.go.kr/bill/billDetail.d...           9700480
# 98  https://likms.assembly.go.kr/bill/billDetail.d...           9700341
# 99  https://likms.assembly.go.kr/bill/billDetail.d...           9700341
#
# [100 rows x 25 columns]

# %%
list_df = []
list_df.append(df)

# %%
from tqdm import tqdm
for i in tqdm(range(1, 36)):
    api_dict['pIndex'] = str(i)
    r = requests.get(url, params=api_dict)
    data = json.loads(r.text)
    df = pd.json_normalize(data['nwbpacrgavhjryiph'][1]['row'])
    list_df.append(df)
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]
# 100%|██████████| 35/35 [00:10<00:00,  3.45it/s]

# %%
len(list_df)
# Out:
# 36

# %%
list_df[0]
# Out:
#    AGE  BILL_NO                                            BILL_NM BILL_KIND  \
# 0   21  2126436            국립묘지의 설치 및 운영에 관한 법률 일부개정법률안(대안)(정무위원장)       법률안
# 1   21  2126458                   자동차손해배상 보장법 일부개정법률안(대안)(국토교통위원장)       법률안
# 2   21  2126447               유사수신행위의 규제에 관한 법률 일부개정법률안(대안)(정무위원장)       법률안
# 3   21  2126446  전기통신금융사기 피해 방지 및 피해금 환급에 관한 특별법 일부개정법률안(대안)(정무...       법률안
# 4   21  2126435                       공익신고자 보호법 일부개정법률안(대안)(정무위원장)       법률안
# ..  ..      ...                                                ...       ...
# 95  21  2126215                         도로교통법 일부개정법률안(대안)(행정안전위원장)       법률안
# 96  21  2126203  제주특별자치도 설치 및 국제자유도시 조성을 위한 특별법 일부개정법률안(대안)(행정안...       법률안
# 97  21  2126226  제주4·3사건 진상규명 및 희생자 명예회복에 관한 특별법 일부개정법률안(대안)(행정...       법률안
# 98  21  2126216                 마약류 관리에 관한 법률 일부개정법률안(대안)(보건복지위원장)       법률안
# 99  21  2126219                          화장품법 일부개정법률안(대안)(보건복지위원장)       법률안
#
#    PROPOSER COMMITTEE_NM PROC_RESULT_CD  VOTE_TCNT  YES_TCNT  NO_TCNT  ...  \
# 0     정무위원장        정무위원회           원안가결      232.0     232.0      NaN  ...
# 1   국토교통위원장      국토교통위원회           원안가결      192.0     189.0      1.0  ...
# 2     정무위원장        정무위원회           원안가결      235.0     234.0      NaN  ...
# 3     정무위원장        정무위원회           원안가결      244.0     244.0      NaN  ...
# 4     정무위원장        정무위원회           원안가결      238.0     237.0      NaN  ...
# ..      ...          ...            ...        ...       ...      ...  ...
# 95  행정안전위원장      행정안전위원회           원안가결      224.0     223.0      NaN  ...
# 96  행정안전위원장      행정안전위원회           원안가결      216.0     211.0      NaN  ...
# 97  행정안전위원장      행정안전위원회           원안가결      211.0     201.0      1.0  ...
# 98  보건복지위원장      보건복지위원회           원안가결      229.0     228.0      NaN  ...
# 99  보건복지위원장      보건복지위원회           원안가결      227.0     224.0      NaN  ...
#
#     LAW_SUBMIT_DT LAW_PRESENT_DT LAW_PROC_DT RGS_PRESENT_DT RGS_PROC_DT  \
# 0      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 1      2023-12-21     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 2      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 3      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# 4      2023-12-14     2024-01-31  2024-01-31     2024-02-01  2024-02-01
# ..            ...            ...         ...            ...         ...
# 95     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
# 96     2023-05-24     2023-07-26  2024-01-08     2024-01-09  2024-01-09
# 97     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
# 98     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
# 99     2023-11-23     2024-01-08  2024-01-08     2024-01-09  2024-01-09
#
#    CURR_TRANS_DT ANNOUNCE_DT                             BILL_ID  \
# 0           None        None  PRC_C2A3D1G2C1T3N1O6W5B8M5W5G8I7N9
# 1           None        None  PRC_D2B3N1T2T2N0K1Q9S3Q4A0Y6R2P3E6
# 2           None        None  PRC_T2B3L1O2N1E3J1V6X5F2Q1K6B9N5G0
# 3           None        None  PRC_Y2D3T1U2D1G3D1O6S5D0T1V8L5G5S4
# 4           None        None  PRC_P2F3H1P2Y1K3Q1Y6L5Z4U1D4R0Q2N4
# ..           ...         ...                                 ...
# 95    2024-01-19  2024-01-30  PRC_N2J3F1Q1H2G1I2O2E3E8Y4W2K2N3J1
# 96    2024-01-19  2024-01-30  PRC_W2P3C0W5F2X4F1T6A1B8O4O8O1Q0E1
# 97    2024-01-19  2024-01-30  PRC_A2I3H1Y1R2E2Q2T1E4L8P1E4A5I8V9
# 98    2024-01-26        None  PRC_J2L3Y1F1Q2A2C2P0L4Y0D1M1D1H0C3
# 99    2024-01-26        None  PRC_G2X3R1R1K2H2Y2R0P4B2E5J4D7N5V8
#
#                                              LINK_URL CURR_COMMITTEE_ID
# 0   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# 1   https://likms.assembly.go.kr/bill/billDetail.d...           9700407
# 2   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# 3   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# 4   https://likms.assembly.go.kr/bill/billDetail.d...           9700008
# ..                                                ...               ...
# 95  https://likms.assembly.go.kr/bill/billDetail.d...           9700480
# 96  https://likms.assembly.go.kr/bill/billDetail.d...           9700480
# 97  https://likms.assembly.go.kr/bill/billDetail.d...           9700480
# 98  https://likms.assembly.go.kr/bill/billDetail.d...           9700341
# 99  https://likms.assembly.go.kr/bill/billDetail.d...           9700341
#
# [100 rows x 25 columns]

# %%
del list_df[0]
len(list_df)
df_concat = pd.concat(list_df, axis=0)
df_concat
df_concat['BILL_ID'].value_counts()
df_concat_before_mabu = df_concat[df_concat['RGS_PROC_DT'] < '2021-06-03']
df_concat_before_mabu['RGS_PROC_DT'].max()
df_concat_before_mabu['RGS_PROC_DT'].min()
bill_id_list = list(df_concat_before_mabu['BILL_ID'].unique())
len(bill_id_list)
url = 'https://open.assembly.go.kr/portal/openapi/nojepdqqaweusdfbi'
api_dict = {'key': api_key,
            'type': 'json',
            'pIndex': '1',
            'pSize': '400',
            'AGE': '21'}

api_dict['pIndex'] = '1'
api_dict['BILL_ID'] = bill_id_list[0]
r = requests.get(url, params=api_dict)
data = json.loads(r.text)
data['nojepdqqaweusdfbi'][1]['row']
len(data['nojepdqqaweusdfbi'][1]['row'])
import time
df_list = []
for bill_id in tqdm(bill_id_list):
    api_dict['BILL_ID'] = bill_id
    r = requests.get(url, params=api_dict)
    data = json.loads(r.text)
    try:
        df = pd.json_normalize(data['nojepdqqaweusdfbi'][1]['row'])
        df_list.append(df)
    except:
        pass
    time.sleep(0.1)
len(df_list)
df
pv1= df.pivot(values='RESULT_VOTE_MOD', index='MEMBER_NO', columns='BILL_NO')
pv2= df_list[0].pivot(values='RESULT_VOTE_MOD', index='MEMBER_NO', columns='BILL_NO')
pv1
pd.merge(pv1, pv2, 'outer', on='MEMBER_NO')
pv0 = df_list[0].pivot(values='RESULT_VOTE_MOD', index='MEMBER_NO', columns='BILL_NO')
for df in df_list[1:]:
    pv1 = df.pivot(values='RESULT_VOTE_MOD', index='MEMBER_NO', columns='BILL_NO')
    pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
pv0
vote_table = pv0
for df in df_list:
    df.to_csv(f'표결정보/{df["BILL_NO"][0]}.csv')
# Out:
# 100%|██████████| 975/975 [07:02<00:00,  2.31it/s]
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# ...
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/578626277.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')

# %%
import pandas as pd
from glob import glob
file_list = glob('표결정보/*')

# %%
df_list = []
for file_name in file_list:
    df = pd.read_csv(file_name)
    df_list.append(df)

# %%
pv0 = df_list[0].pivot(values='RESULT_VOTE_MOD', index='MEMBER_NO', columns='BILL_NO')
for df in df_list[1:]:
    pv1 = df.pivot(values='RESULT_VOTE_MOD', index='MEMBER_NO', columns='BILL_NO')
    pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
pv0
vote_table = pv0
# Out:
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# ...
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')
# /tmp/ipykernel_11352/3785313097.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pv0 = pd.merge(pv0, pv1, 'outer', on='MEMBER_NO')

# %%
vote_table
# Out:
# BILL_NO       2104658 2105495 2103406 2106817 2102111 2105940 2106039 2102238  \
# MEMBER_NO
# 2100000000001      불참      찬성      불참      불참      기권      찬성      찬성      찬성
# 2100000000002      불참      불참      찬성      찬성      찬성      찬성      찬성      찬성
# 2100000000003      찬성      찬성      찬성      찬성      찬성      찬성      찬성      찬성
# 2100000000004      반대      불참      불참      기권      찬성      찬성      찬성      불참
# 2100000000005      찬성      찬성      찬성      찬성      찬성      기권      찬성      찬성
# ...               ...     ...     ...     ...     ...     ...     ...     ...
# 2100000000297      불참      찬성      불참      불참      찬성      찬성      찬성      기권
# 2100000000298      반대      불참      기권      기권      불참      찬성      찬성      불참
# 2100000000299      찬성      찬성      찬성      찬성      찬성      찬성      찬성      찬성
# 2100000000300      찬성      불참      불참      불참      찬성      찬성      찬성      찬성
# 2100000000301     NaN     NaN     NaN      찬성     NaN     NaN     NaN     NaN
#
# BILL_NO       2101482 2101640  ... 2102401 2107887 2106226 2102375 2104925  \
# MEMBER_NO                      ...
# 2100000000001      찬성      기권  ...      찬성      불참      찬성      기권      찬성
# 2100000000002      찬성      기권  ...      불참      기권      찬성      찬성      기권
# 2100000000003      찬성      찬성  ...      찬성      찬성      찬성      찬성      찬성
# 2100000000004      불참      불참  ...      기권      기권      찬성      기권      반대
# 2100000000005      찬성      찬성  ...      찬성      찬성      찬성      찬성      찬성
# ...               ...     ...  ...     ...     ...     ...     ...     ...
# 2100000000297      찬성      반대  ...      찬성      불참      불참      찬성      찬성
# 2100000000298      찬성      찬성  ...      불참      기권      찬성      불참      찬성
# 2100000000299      찬성      찬성  ...      찬성      찬성      찬성      찬성      찬성
# 2100000000300      불참      불참  ...      찬성      불참      찬성      찬성      찬성
# 2100000000301     NaN     NaN  ...     NaN      찬성     NaN     NaN     NaN
#
# BILL_NO       2105501 2103050 2106288 2106258 2106295
# MEMBER_NO
# 2100000000001      찬성      찬성      불참      찬성      찬성
# 2100000000002      불참      찬성      반대      찬성      찬성
# 2100000000003      찬성      찬성      찬성      찬성      찬성
# 2100000000004      기권      찬성      불참      불참      불참
# 2100000000005      찬성      찬성      기권      기권      찬성
# ...               ...     ...     ...     ...     ...
# 2100000000297      찬성      불참      불참      반대      불참
# 2100000000298      불참      기권      기권      찬성      기권
# 2100000000299      찬성      찬성      찬성      찬성      찬성
# 2100000000300      찬성      찬성      찬성      찬성      찬성
# 2100000000301     NaN     NaN     NaN     NaN     NaN
#
# [301 rows x 819 columns]

# %%
vote_table.to_csv('vote_table.csv')

# %%
vote_table = vote_table.reindex(sorted(vote_table.columns), axis=1)

# %%
vote_table.reindex(sorted(vote_table.index), axis=0)
# Out:
# BILL_NO       2100014 2100015 2100101 2100117 2100178 2100187 2100225 2100266  \
# MEMBER_NO
# 2100000000001      불참      불참      기권      불참      찬성      기권      찬성      기권
# 2100000000002      불참      불참      찬성      불참      찬성      기권      기권      불참
# 2100000000003      찬성      찬성      찬성      찬성      찬성      찬성      찬성      찬성
# 2100000000004      불참      불참      찬성      찬성      찬성      찬성      찬성      기권
# 2100000000005      찬성      찬성      찬성      찬성      찬성      찬성      찬성      찬성
# ...               ...     ...     ...     ...     ...     ...     ...     ...
# 2100000000297      반대      반대      기권      불참      불참      불참      찬성      불참
# 2100000000298      불참      불참      찬성      찬성      불참      불참      찬성      불참
# 2100000000299      찬성      찬성      찬성      찬성      찬성      찬성      찬성      찬성
# 2100000000300      찬성      찬성      찬성      불참      찬성      찬성      찬성      불참
# 2100000000301     NaN     NaN     NaN      불참     NaN     NaN     NaN     NaN
#
# BILL_NO       2100267 2100273  ... 2110274 2110275 2110276 2110277 2110278  \
# MEMBER_NO                      ...
# 2100000000001      기권      기권  ...      불참      불참      불참      불참      불참
# 2100000000002      불참      기권  ...      불참      불참      찬성      불참      찬성
# 2100000000003      찬성      찬성  ...      찬성      찬성      찬성      찬성      찬성
# 2100000000004      반대      기권  ...      불참      불참      찬성      불참      불참
# 2100000000005      찬성      찬성  ...      찬성      찬성      찬성      찬성      찬성
# ...               ...     ...  ...     ...     ...     ...     ...     ...
# 2100000000297      찬성      찬성  ...      불참      불참      불참      불참      불참
# 2100000000298      불참      불참  ...      불참      불참      찬성      불참      불참
# 2100000000299      찬성      찬성  ...      찬성      찬성      찬성      찬성      찬성
# 2100000000300      불참      찬성  ...      불참      불참      불참      불참      불참
# 2100000000301     NaN     NaN  ...      불참      불참      찬성      불참      불참
#
# BILL_NO       2110279 2110280 2110281 2110282 2110283
# MEMBER_NO
# 2100000000001      불참      불참      불참      불참      불참
# 2100000000002      찬성      찬성      찬성      불참      찬성
# 2100000000003      찬성      찬성      찬성      찬성      기권
# 2100000000004      불참      불참      불참      찬성      불참
# 2100000000005      찬성      찬성      찬성      찬성      찬성
# ...               ...     ...     ...     ...     ...
# 2100000000297      불참      불참      불참      불참      불참
# 2100000000298      불참      불참      불참      찬성      불참
# 2100000000299      찬성      찬성      찬성      찬성      찬성
# 2100000000300      불참      불참      불참      불참      불참
# 2100000000301      불참      불참      불참      불참      불참
#
# [301 rows x 819 columns]

# %%
vote_table = vote_table.reindex(sorted(vote_table.index), axis=0)

# %%
mapping = {'찬성': 1, '반대': 2, '기권': 3, '불참': 0}
vote_table_num = vote_table.applymap(lambda x: (4 if x!=x else mapping[x]))

# %%
vote_table_num
# Out:
# BILL_NO        2100014  2100015  2100101  2100117  2100178  2100187  2100225  \
# MEMBER_NO
# 2100000000001        0        0        3        0        1        3        1
# 2100000000002        0        0        1        0        1        3        3
# 2100000000003        1        1        1        1        1        1        1
# 2100000000004        0        0        1        1        1        1        1
# 2100000000005        1        1        1        1        1        1        1
# ...                ...      ...      ...      ...      ...      ...      ...
# 2100000000297        2        2        3        0        0        0        1
# 2100000000298        0        0        1        1        0        0        1
# 2100000000299        1        1        1        1        1        1        1
# 2100000000300        1        1        1        0        1        1        1
# 2100000000301        4        4        4        0        4        4        4
#
# BILL_NO        2100266  2100267  2100273  ...  2110274  2110275  2110276  \
# MEMBER_NO                                 ...
# 2100000000001        3        3        3  ...        0        0        0
# 2100000000002        0        0        3  ...        0        0        1
# 2100000000003        1        1        1  ...        1        1        1
# 2100000000004        3        2        3  ...        0        0        1
# 2100000000005        1        1        1  ...        1        1        1
# ...                ...      ...      ...  ...      ...      ...      ...
# 2100000000297        0        1        1  ...        0        0        0
# 2100000000298        0        0        0  ...        0        0        1
# 2100000000299        1        1        1  ...        1        1        1
# 2100000000300        0        0        1  ...        0        0        0
# 2100000000301        4        4        4  ...        0        0        1
#
# BILL_NO        2110277  2110278  2110279  2110280  2110281  2110282  2110283
# MEMBER_NO
# 2100000000001        0        0        0        0        0        0        0
# 2100000000002        0        1        1        1        1        0        1
# 2100000000003        1        1        1        1        1        1        3
# 2100000000004        0        0        0        0        0        1        0
# 2100000000005        1        1        1        1        1        1        1
# ...                ...      ...      ...      ...      ...      ...      ...
# 2100000000297        0        0        0        0        0        0        0
# 2100000000298        0        0        0        0        0        1        0
# 2100000000299        1        1        1        1        1        1        1
# 2100000000300        0        0        0        0        0        0        0
# 2100000000301        0        0        0        0        0        0        0
#
# [301 rows x 819 columns]

# %%
vote_table_num.to_csv('vote_table_num.csv')

# %%
df_merged = pd.concat(df_list, axis=0)

# %%
df_merged
# Out:
#      Unnamed: 0 HG_NM HJ_NM POLY_NM          ORIG_NM      MEMBER_NO  POLY_CD  \
# 0             0   김선교   金善敎    국민의힘        경기 여주시양평군  2100000000041   101210
# 1             1   이용빈   李龍彬  더불어민주당          광주 광산구갑  2100000000202   101182
# 2             2   조명희   曺明姬    국민의힘             비례대표  2100000000254   101210
# 3             3   홍성국   洪性國  더불어민주당         세종특별자치시갑  2100000000293   101182
# 4             4    이영    李永    국민의힘             비례대표  2100000000200   101210
# ..          ...   ...   ...     ...              ...            ...      ...
# 295         295   박수영   朴洙瑩    국민의힘           부산 남구갑  2100000000098   101210
# 296         296   이양수   李亮壽    국민의힘  강원 속초시인제군고성군양양군  2100000000199   101210
# 297         297   유기홍   柳基洪  더불어민주당          서울 관악구갑  2100000000161   101182
# 298         298    박진    朴振    국민의힘          서울 강남구을  2100000000106   101210
# 299         299   김태호   金台鎬    국민의힘  경남 산청군함양군거창군합천군  2100000000069   101210
#
#      ORIG_CD        VOTE_DATE  BILL_NO  ... RESULT_VOTE_MOD  DEPT_CD  \
# 0      80194  20201210 142953  2104658  ...              불참  9771195
# 1      50013  20201210 142953  2104658  ...              찬성  9771158
# 2     240001  20201210 142953  2104658  ...              불참  9771247
# 3     210025  20201210 142953  2104658  ...              찬성  9771167
# 4     240001  20201210 142953  2104658  ...              불참  9771251
# ..       ...              ...      ...  ...             ...      ...
# 295    20011  20201209 174555  2106295  ...              찬성  9771135
# 296   210032  20201209 174555  2106295  ...              찬성  9771003
# 297    10062  20201209 174555  2106295  ...              찬성  9771121
# 298    10069  20201209 174555  2106295  ...              찬성  9771125
# 299   160125  20201209 174555  2106295  ...              찬성  9771237
#
#     CURR_COMMITTEE_ID DISP_ORDER  \
# 0             9700006          0
# 1             9700006          0
# 2             9700006          0
# 3             9700006          0
# 4             9700006          0
# ..                ...        ...
# 295           9700008          0
# 296           9700008          0
# 297           9700008          0
# 298           9700008          0
# 299           9700008          0
#
#                                               BILL_URL  \
# 0    http://likms.assembly.go.kr/bill/billDetail.do...
# 1    http://likms.assembly.go.kr/bill/billDetail.do...
# 2    http://likms.assembly.go.kr/bill/billDetail.do...
# 3    http://likms.assembly.go.kr/bill/billDetail.do...
# 4    http://likms.assembly.go.kr/bill/billDetail.do...
# ..                                                 ...
# 295  http://likms.assembly.go.kr/bill/billDetail.do...
# 296  http://likms.assembly.go.kr/bill/billDetail.do...
# 297  http://likms.assembly.go.kr/bill/billDetail.do...
# 298  http://likms.assembly.go.kr/bill/billDetail.do...
# 299  http://likms.assembly.go.kr/bill/billDetail.do...
#
#                                          BILL_NAME_URL  SESSION_CD  \
# 0    http://likms.assembly.go.kr/bill/billDetail.do...         383
# 1    http://likms.assembly.go.kr/bill/billDetail.do...         383
# 2    http://likms.assembly.go.kr/bill/billDetail.do...         383
# 3    http://likms.assembly.go.kr/bill/billDetail.do...         383
# 4    http://likms.assembly.go.kr/bill/billDetail.do...         383
# ..                                                 ...         ...
# 295  http://likms.assembly.go.kr/bill/billDetail.do...         382
# 296  http://likms.assembly.go.kr/bill/billDetail.do...         382
# 297  http://likms.assembly.go.kr/bill/billDetail.do...         382
# 298  http://likms.assembly.go.kr/bill/billDetail.do...         382
# 299  http://likms.assembly.go.kr/bill/billDetail.do...         382
#
#      CURRENTS_CD AGE   MONA_CD
# 0              1  21  JNL7001A
# 1              1  21  GKD32201
# 2              1  21  S741317G
# 3              1  21  2N793392
# 4              1  21  1X376850
# ..           ...  ..       ...
# 295           15  21  FU87526G
# 296           15  21  S9U45255
# 297           15  21  8FC9697X
# 298           15  21  QKO6165V
# 299           15  21  P0F1530P
#
# [245700 rows x 24 columns]

# %%
df_merged['VOTE_DATE'].max()
# Out:
# '20210521 121253'

# %%
df_merged['RESULT_VOTE_MOD'].value_counts()
# Out:
# 찬성    186511
# 불참     46964
# 기권      8815
# 반대      3410
# Name: RESULT_VOTE_MOD, dtype: int64

# %%
df_party = df_merged[['POLY_NM', 'MEMBER_NO']]

# %%
df_party = df_party.drop_duplicates()

# %%
df_party = df_party.sort_values('MEMBER_NO')

# %%
df_party.to_csv('member_no_party.csv', index=False)

# %%
df_member_info = df_merged[['HG_NM', 'HJ_NM', 'POLY_NM', 'ORIG_NM', 'MEMBER_NO', 'POLY_CD', 'ORIG_CD']]

# %%
df_member_info = df_member_info.drop_duplicates()

# %%
df_member_info = df_member_info.sort_values('MEMBER_NO')

# %%
df_member_info.to_csv('member_info.csv', index=False)

# %% [markdown]
# # After w-nominate

# %%
df_party = pd.read_csv('member_no_party.csv', index_col=None)
df_member_info = pd.read_csv('member_info.csv', index_col=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_result = pd.read_csv('w-nominate-result.csv')
df_result
# Out:
#         Unnamed: 0   party  correctYea  wrongYea  wrongNay  correctNay  \
# 0    2100000000001    국민의힘       167.0      59.0      30.0        49.0
# 1    2100000000002    국민의힘       259.0      67.0      25.0        67.0
# 2    2100000000003  더불어민주당       522.0       7.0       0.0         0.0
# 3    2100000000004    국민의힘       187.0      53.0      22.0        74.0
# 4    2100000000005  더불어민주당       503.0      16.0       0.0         4.0
# ..             ...     ...         ...       ...       ...         ...
# 296  2100000000297    국민의힘       200.0      49.0       9.0        19.0
# 297  2100000000298     무소속       277.0      58.0      13.0        40.0
# 298  2100000000299  더불어민주당       522.0       2.0       0.0         0.0
# 299  2100000000300  더불어민주당       233.0       2.0       0.0         0.0
# 300  2100000000301  더불어민주당        58.0       0.0       0.0         0.0
#
#           GMP        CC   coord1D   coord2D  se1D  se2D  corr.1
# 0    0.574544  0.708197  0.648437  0.575311   0.0   0.0     0.0
# 1    0.623289  0.779904  0.647253  0.205548   0.0   0.0     0.0
# 2    0.933632  0.986767 -0.390132  0.641389   0.0   0.0     0.0
# 3    0.601663  0.776786  0.722683 -0.124505   0.0   0.0     0.0
# 4    0.890621  0.969407 -0.076170 -0.413134   0.0   0.0     0.0
# ..        ...       ...       ...       ...   ...   ...     ...
# 296  0.626853  0.790614  0.486069  0.873920   0.0   0.0     0.0
# 297  0.630910  0.817010  0.539827  0.162076   0.0   0.0     0.0
# 298  0.972824  0.996183 -0.519860  0.066851   0.0   0.0     0.0
# 299  0.950404  0.991489 -0.567713  0.823226   0.0   0.0     0.0
# 300  0.996492  1.000000 -0.949757 -0.082126   0.0   0.0     0.0
#
# [301 rows x 13 columns]

# %%
df_member_info.set_index('MEMBER_NO')
# Out:
#               HG_NM HJ_NM POLY_NM    ORIG_NM  POLY_CD  ORIG_CD
# MEMBER_NO
# 2100000000001   강기윤   姜起潤    국민의힘  경남 창원시성산구   101210   160124
# 2100000000002   강대식   姜大植    국민의힘     대구 동구을   101210    30005
# 2100000000003   강득구   姜得求  더불어민주당  경기 안양시만안구   101182    80017
# 2100000000004   강민국   姜旻局    국민의힘    경남 진주시을   101210   160008
# 2100000000005   강민정   姜旼姃  더불어민주당       비례대표   101182   240001
# ...             ...   ...     ...        ...      ...      ...
# 2100000000297   홍준표   洪準杓    국민의힘    대구 수성구을   101210    30016
# 2100000000298  황보승희  皇甫承希     무소속   부산 중구영도구   101030    20049
# 2100000000299   황운하   黃雲夏  더불어민주당      대전 중구   101182    60003
# 2100000000300    황희    黃熙  더불어민주당    서울 양천구갑   101182    10042
# 2100000000301   김의겸   金宜謙  더불어민주당       비례대표   101182   240001
#
# [301 rows x 6 columns]

# %%
df_join = pd.merge(df_result, df_member_info, left_on='Unnamed: 0', right_on='MEMBER_NO')

# %%
df_join
# Out:
#         Unnamed: 0   party  correctYea  wrongYea  wrongNay  correctNay  \
# 0    2100000000001    국민의힘       167.0      59.0      30.0        49.0
# 1    2100000000002    국민의힘       259.0      67.0      25.0        67.0
# 2    2100000000003  더불어민주당       522.0       7.0       0.0         0.0
# 3    2100000000004    국민의힘       187.0      53.0      22.0        74.0
# 4    2100000000005  더불어민주당       503.0      16.0       0.0         4.0
# ..             ...     ...         ...       ...       ...         ...
# 296  2100000000297    국민의힘       200.0      49.0       9.0        19.0
# 297  2100000000298     무소속       277.0      58.0      13.0        40.0
# 298  2100000000299  더불어민주당       522.0       2.0       0.0         0.0
# 299  2100000000300  더불어민주당       233.0       2.0       0.0         0.0
# 300  2100000000301  더불어민주당        58.0       0.0       0.0         0.0
#
#           GMP        CC   coord1D   coord2D  se1D  se2D  corr.1 HG_NM HJ_NM  \
# 0    0.574544  0.708197  0.648437  0.575311   0.0   0.0     0.0   강기윤   姜起潤
# 1    0.623289  0.779904  0.647253  0.205548   0.0   0.0     0.0   강대식   姜大植
# 2    0.933632  0.986767 -0.390132  0.641389   0.0   0.0     0.0   강득구   姜得求
# 3    0.601663  0.776786  0.722683 -0.124505   0.0   0.0     0.0   강민국   姜旻局
# 4    0.890621  0.969407 -0.076170 -0.413134   0.0   0.0     0.0   강민정   姜旼姃
# ..        ...       ...       ...       ...   ...   ...     ...   ...   ...
# 296  0.626853  0.790614  0.486069  0.873920   0.0   0.0     0.0   홍준표   洪準杓
# 297  0.630910  0.817010  0.539827  0.162076   0.0   0.0     0.0  황보승희  皇甫承希
# 298  0.972824  0.996183 -0.519860  0.066851   0.0   0.0     0.0   황운하   黃雲夏
# 299  0.950404  0.991489 -0.567713  0.823226   0.0   0.0     0.0    황희    黃熙
# 300  0.996492  1.000000 -0.949757 -0.082126   0.0   0.0     0.0   김의겸   金宜謙
#
#     POLY_NM    ORIG_NM      MEMBER_NO  POLY_CD  ORIG_CD
# 0      국민의힘  경남 창원시성산구  2100000000001   101210   160124
# 1      국민의힘     대구 동구을  2100000000002   101210    30005
# 2    더불어민주당  경기 안양시만안구  2100000000003   101182    80017
# 3      국민의힘    경남 진주시을  2100000000004   101210   160008
# 4    더불어민주당       비례대표  2100000000005   101182   240001
# ..      ...        ...            ...      ...      ...
# 296    국민의힘    대구 수성구을  2100000000297   101210    30016
# 297     무소속   부산 중구영도구  2100000000298   101030    20049
# 298  더불어민주당      대전 중구  2100000000299   101182    60003
# 299  더불어민주당    서울 양천구갑  2100000000300   101182    10042
# 300  더불어민주당       비례대표  2100000000301   101182   240001
#
# [301 rows x 20 columns]

# %%
df_join.groupby('party').mean()
# Out:
#           Unnamed: 0  correctYea   wrongYea   wrongNay  correctNay       GMP  \
# party
# 국민의힘    2.100000e+12  289.818182  45.663636  14.990909   45.090909  0.714111
# 기본소득당   2.100000e+12  431.000000  39.000000   8.000000    4.000000  0.730339
# 더불어민주당  2.100000e+12  469.335329   4.245509   0.101796    0.371257  0.959419
# 무소속     2.100000e+12  403.071429  18.857143   4.714286   12.928571  0.860800
# 열린민주당   2.100000e+12  163.000000   4.000000   0.000000    0.000000  0.908340
# 정의당     2.100000e+12  461.833333  23.333333   1.666667    7.166667  0.866562
# 한국의희망   2.100000e+12  521.000000   1.000000   0.000000    0.000000  0.983892
#
#               CC   coord1D   coord2D  se1D  se2D  corr.1     MEMBER_NO  \
# party
# 국민의힘    0.849258  0.440448  0.044822   0.0   0.0     0.0  2.100000e+12
# 기본소득당   0.902490  0.160257 -0.613663   0.0   0.0     0.0  2.100000e+12
# 더불어민주당  0.990927 -0.495468  0.040221   0.0   0.0     0.0  2.100000e+12
# 무소속     0.943857 -0.200993  0.125744   0.0   0.0     0.0  2.100000e+12
# 열린민주당   0.976048 -0.276512  0.387001   0.0   0.0     0.0  2.100000e+12
# 정의당     0.950292  0.013049 -0.729633   0.0   0.0     0.0  2.100000e+12
# 한국의희망   0.998084 -0.533193  0.235504   0.0   0.0     0.0  2.100000e+12
#
#          POLY_CD        ORIG_CD
# party
# 국민의힘    101210.0  124672.245455
# 기본소득당   101208.0  240001.000000
# 더불어민주당  101182.0   91297.422619
# 무소속     101030.0  104334.928571
# 열린민주당   101203.0  240001.000000
# 정의당     101180.0  213366.000000
# 한국의희망   101212.0   50004.000000

# %%
mean_pos = df_join.groupby('party').mean()

# %%
colors_dict = {'국민의힘': '#E61E2B', '더불어민주당': '#3544A4', '정의당': '#FFED00', '진보당': '#D6001C', '기본소득당': '#00D2C3', '무소속': 'lightgray'}
#marekrs_dict = {'국민의힘': }

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 9))
ax1 = fig.add_subplot(111)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=80, alpha=0.8)

plt.show()

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 9))
ax1 = fig.add_subplot(111)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=80, alpha=0.8)

for i in range(len(df_join)):
    plt.text(df_join['coord1D'][i]+0.005, df_join['coord2D'][i]+0.005, df_join['HG_NM'][i], size=8)

plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 9))
ax1 = fig.add_subplot(111)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=80, alpha=0.6, linewidths=1, edgecolors='lightgray')

for i in range(len(df_join)):
    if df_join['HG_NM'][i] in ['박병석', '김진표', '서병수', '변재일', '이낙연',
                               '설훈', '이상민', '송영길', '조정식', '안민석', '서병수',
                               '주호영', '정진석', '조경태', '홍준표',
                               '홍익표', '박광온', '박홍근', '윤호중', '김태년',
                               '윤재옥', '주호영', '권성동', '김기현',
                               '이재명', '강민정', '정경희', '안철수', '김예지', '허종식', '한준호', '민형배', '윤미향',
                               '심상정', '용혜인', '강성희', '조정훈', '김남국']:
        plt.text(df_join['coord1D'][i], df_join['coord2D'][i], df_join['HG_NM'][i], size=12)

plt.show()

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(111)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=200, alpha=0.7)

for i in range(len(df_join)):
    if df_join['HG_NM'][i] in ['박병석', '김진표', '서병수', '변재일', '이낙연',
                               '설훈', '이상민', '송영길', '안민석', '서병수',
                               '주호영', '정진석', '조경태', '홍준표',
                               '홍익표', '박광온',
                               '윤재옥', '주호영', '권성동', '김기현',
                               '이재명', '강민정', '정경희', '안철수', '김예지', '한준호', '민형배', '윤미향',
                               '심상정', '용혜인', '강성희']:
        plt.text(df_join['coord1D'][i], df_join['coord2D'][i], df_join['HG_NM'][i], size=14, weight='semibold')
plt.legend(colors_dict.keys())
plt.title('21대 국회 본회의 w-nominate 분석', size=12)
plt.savefig('main_display_plot.png', dpi=300, transparent=False, facecolor='white')
plt.show()

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(111)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=200, alpha=0.7)

for party_name in colors_dict:
    if party_name in ['진보당', '기본소득당', '무소속']:
        continue
    ax1.vlines(mean_pos['coord1D'][party_name], -1.2, 1.2, colors_dict[party_name], 'dashed')
    plt.text(mean_pos['coord1D'][party_name]-0.05, -1.03, f"{mean_pos['coord1D'][party_name]:0.2f}", size=16, weight='semibold', color='black')

for i in range(len(df_join)):
    if df_join['HG_NM'][i] in ['박병석', '김진표', '서병수', '변재일', '이낙연',
                               '설훈', '이상민', '송영길', '안민석', '서병수',
                               '주호영', '정진석', '조경태', '홍준표',
                               '홍익표', '박광온',
                               '윤재옥', '주호영', '권성동', '김기현',
                               '이재명', '강민정', '정경희', '안철수', '김예지', '한준호', '민형배', '윤미향',
                               '심상정', '용혜인', '강성희']:
        plt.text(df_join['coord1D'][i], df_join['coord2D'][i], df_join['HG_NM'][i], size=14, weight='semibold')
plt.ylim(-1.1, 1.1)
plt.legend(colors_dict.keys())
plt.title('21대 국회 본회의 w-nominate 분석 (마부작침 분석 재현; 2020-05-30 ~ 2021-06-03)', size=16)
plt.savefig('main_display_plot_with_vline.png', dpi=300, transparent=False, facecolor='white')
plt.show()

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 9))
ax1 = fig.add_subplot(111)
xlim = (-0.5, +0.8)
ylim = (-0.9, 0.3)
plt.xlim(*xlim)
plt.ylim(*ylim)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=80, alpha=0.6)

for i in range(len(df_join)):
    if xlim[0] > df_join['coord1D'][i] or xlim[1] < df_join['coord1D'][i]:
        continue
    if ylim[0] > df_join['coord2D'][i] or ylim[1] < df_join['coord2D'][i]:
        continue
    plt.text(df_join['coord1D'][i], df_join['coord2D'][i], df_join['HG_NM'][i], size=10)

plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.rcParams["font.family"] = 'NanumGothic'
fig = plt.figure(figsize=(14, 9))
ax1 = fig.add_subplot(111)
xlim = (-0.5, +0.8)
ylim = (-0.9, 0.3)
plt.xlim(*xlim)
plt.ylim(*ylim)
for party_name in colors_dict:
    ax1.scatter(df_result[df_result['party']==party_name]['coord1D'], df_result[df_result['party']==party_name]['coord2D'], c=colors_dict[party_name], s=80, alpha=0.6)

for i in range(len(df_join)):
    if xlim[0] > df_join['coord1D'][i] or xlim[1] < df_join['coord1D'][i]:
        continue
    if ylim[0] > df_join['coord2D'][i] or ylim[1] < df_join['coord2D'][i]:
        continue
    if df_join['HG_NM'][i] in ['박병석', '김진표', '서병수', '변재일', '이낙연',
                               '설훈', '이상민', '송영길', '조정식', '안민석', '서병수',
                               '주호영', '정진석', '조경태', '홍준표',
                               '홍익표', '박광온', '박홍근', '윤호중', '김태년',
                               '윤재옥', '주호영', '권성동', '김기현',
                               '이재명', '강민정', '정경희', '안철수', '김예지', '허종식', '한준호', '민형배', '윤미향',
                               '심상정', '용혜인', '강성희', '조정훈', '김남국']:
        plt.text(df_join['coord1D'][i], df_join['coord2D'][i], df_join['HG_NM'][i], size=10)

plt.tight_layout()
plt.show()
